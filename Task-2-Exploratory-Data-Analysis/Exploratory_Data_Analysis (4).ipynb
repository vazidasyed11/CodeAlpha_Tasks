# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
data = {
    "Student": [
        "Student 1", "Student 2", "Student 3", "Student 4", "Student 5",
        "Student 6", "Student 7", "Student 8", "Student 9", "Student 10",
        "Student 11", "Student 12", "Student 13", "Student 14", "Student 15",
        "Student 16", "Student 17", "Student 18", "Student 19", "Student 20"
    ],

    "Study_Hours": [
        2, 4, 6, 8, 3, 5, 7, 1, 9, 4,
        6, 2, 8, 5, 3, 7, 10, 1, 6, 4
    ],

    "Attendance": [
        65, 75, 85, 90, 70, 80, 88, 60, 95, 78,
        84, 68, 92, 82, 72, 89, 98, 55, 86, 76
    ],

    "Assignment_Score": [
        60, 70, 82, 90, 65, 75, 85, 55, 94, 72,
        80, 62, 91, 78, 68, 87, 96, 50, 83, 73
    ],

    "Exam_Score": [
        58, 68, 80, 88, 62, 74, 83, 52, 92, 70,
        78, 60, 89, 76, 65, 85, 95, 48, 81, 71
    ]
}

df = pd.DataFrame(data)

print("Dataset created successfully!")
# Out:
# Dataset created successfully!

# %%
df
# Out:
#        Student  Study_Hours  Attendance  Assignment_Score  Exam_Score
# 0    Student 1            2          65                60          58
# 1    Student 2            4          75                70          68
# 2    Student 3            6          85                82          80
# 3    Student 4            8          90                90          88
# 4    Student 5            3          70                65          62
# 5    Student 6            5          80                75          74
# 6    Student 7            7          88                85          83
# 7    Student 8            1          60                55          52
# 8    Student 9            9          95                94          92
# 9   Student 10            4          78                72          70
# 10  Student 11            6          84                80          78
# 11  Student 12            2          68                62          60
# ...

# %%
df.to_csv("student_performance.csv", index=False)

print("CSV file created successfully!")
# Out:
# CSV file created successfully!

# %%
df.head()
# Out:
#      Student  Study_Hours  Attendance  Assignment_Score  Exam_Score
# 0  Student 1            2          65                60          58
# 1  Student 2            4          75                70          68
# 2  Student 3            6          85                82          80
# 3  Student 4            8          90                90          88
# 4  Student 5            3          70                65          62

# %%
df.tail()
# Out:
#        Student  Study_Hours  Attendance  Assignment_Score  Exam_Score
# 15  Student 16            7          89                87          85
# 16  Student 17           10          98                96          95
# 17  Student 18            1          55                50          48
# 18  Student 19            6          86                83          81
# 19  Student 20            4          76                73          71

# %%
print("Number of rows and columns:", df.shape)
# Out:
# Number of rows and columns: (20, 5)

# %%
print("Column names:")
print(df.columns)
# Out:
# Column names:
# Index(['Student', 'Study_Hours', 'Attendance', 'Assignment_Score',
#        'Exam_Score'],
#       dtype='object')

# %%
print("Data types:")
print(df.dtypes)
# Out:
# Data types:
# Student             object
# Study_Hours          int64
# Attendance           int64
# Assignment_Score     int64
# Exam_Score           int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Student           20 non-null     object
#  1   Study_Hours       20 non-null     int64
#  2   Attendance        20 non-null     int64
#  3   Assignment_Score  20 non-null     int64
#  4   Exam_Score        20 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 932.0+ bytes

# %%
df.describe()
# Out:
#        Study_Hours  Attendance  Assignment_Score  Exam_Score
# count    20.000000     20.0000         20.000000   20.000000
# mean      5.050000     79.4000         75.800000   73.750000
# std       2.625282     11.7312         13.113272   13.356942
# min       1.000000     55.0000         50.000000   48.000000
# 25%       3.000000     71.5000         67.250000   64.250000
# 50%       5.000000     81.0000         76.500000   75.000000
# 75%       7.000000     88.2500         85.500000   83.500000
# max      10.000000     98.0000         96.000000   95.000000

# %%
print("Shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())

print("\nData Types:")
print(df.dtypes)

print("\nDataset Information:")
df.info()

print("\nStatistical Summary:")
display(df.describe())
# Out:
# Shape: (20, 5)
#
# Columns:
# ['Student', 'Study_Hours', 'Attendance', 'Assignment_Score', 'Exam_Score']
#
# Data Types:
# Student             object
# Study_Hours          int64
# Attendance           int64
# Assignment_Score     int64
# Exam_Score           int64
# dtype: object
#
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Student           20 non-null     object
#  1   Study_Hours       20 non-null     int64
#  2   Attendance        20 non-null     int64
#  3   Assignment_Score  20 non-null     int64
#  4   Exam_Score        20 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 932.0+ bytes
#
# Statistical Summary:
#        Study_Hours  Attendance  Assignment_Score  Exam_Score
# count    20.000000     20.0000         20.000000   20.000000
# ...

# %%
print("Missing values in each column:")
print(df.isnull().sum())
# Out:
# Missing values in each column:
# Student             0
# Study_Hours         0
# Attendance          0
# Assignment_Score    0
# Exam_Score          0
# dtype: int64

# %%
print("Number of duplicate rows:", df.duplicated().sum())
# Out:
# Number of duplicate rows: 0

# %%
print("Unique values in each column:")
print(df.nunique())
# Out:
# Unique values in each column:
# Student             20
# Study_Hours         10
# Attendance          20
# Assignment_Score    20
# Exam_Score          20
# dtype: int64

# %%
print("Attendance below 0:", (df["Attendance"] < 0).sum())
print("Attendance above 100:", (df["Attendance"] > 100).sum())

print("Assignment scores below 0:", (df["Assignment_Score"] < 0).sum())
print("Assignment scores above 100:", (df["Assignment_Score"] > 100).sum())

print("Exam scores below 0:", (df["Exam_Score"] < 0).sum())
print("Exam scores above 100:", (df["Exam_Score"] > 100).sum())
# Out:
# Attendance below 0: 0
# Attendance above 100: 0
# Assignment scores below 0: 0
# Assignment scores above 100: 0
# Exam scores below 0: 0
# Exam scores above 100: 0

# %%
print("===== DATA QUALITY CHECK =====")
print("Missing values:", df.isnull().sum().sum())
print("Duplicate rows:", df.duplicated().sum())
print("Invalid attendance values:", ((df["Attendance"] < 0) | (df["Attendance"] > 100)).sum())
print("Invalid assignment scores:", ((df["Assignment_Score"] < 0) | (df["Assignment_Score"] > 100)).sum())
print("Invalid exam scores:", ((df["Exam_Score"] < 0) | (df["Exam_Score"] > 100)).sum())
# Out:
# ===== DATA QUALITY CHECK =====
# Missing values: 0
# Duplicate rows: 0
# Invalid attendance values: 0
# Invalid assignment scores: 0
# Invalid exam scores: 0

# %%
df.describe()
# Out:
#        Study_Hours  Attendance  Assignment_Score  Exam_Score
# count    20.000000     20.0000         20.000000   20.000000
# mean      5.050000     79.4000         75.800000   73.750000
# std       2.625282     11.7312         13.113272   13.356942
# min       1.000000     55.0000         50.000000   48.000000
# 25%       3.000000     71.5000         67.250000   64.250000
# 50%       5.000000     81.0000         76.500000   75.000000
# 75%       7.000000     88.2500         85.500000   83.500000
# max      10.000000     98.0000         96.000000   95.000000

# %%
print("Average Study Hours:", df["Study_Hours"].mean())
print("Average Attendance:", df["Attendance"].mean())
print("Average Assignment Score:", df["Assignment_Score"].mean())
print("Average Exam Score:", df["Exam_Score"].mean())
# Out:
# Average Study Hours: 5.05
# Average Attendance: 79.4
# Average Assignment Score: 75.8
# Average Exam Score: 73.75

# %%
print("Minimum Study Hours:", df["Study_Hours"].min())
print("Maximum Study Hours:", df["Study_Hours"].max())

print("Minimum Attendance:", df["Attendance"].min())
print("Maximum Attendance:", df["Attendance"].max())

print("Minimum Assignment Score:", df["Assignment_Score"].min())
print("Maximum Assignment Score:", df["Assignment_Score"].max())

print("Minimum Exam Score:", df["Exam_Score"].min())
print("Maximum Exam Score:", df["Exam_Score"].max())
# Out:
# Minimum Study Hours: 1
# Maximum Study Hours: 10
# Minimum Attendance: 55
# Maximum Attendance: 98
# Minimum Assignment Score: 50
# Maximum Assignment Score: 96
# Minimum Exam Score: 48
# Maximum Exam Score: 95

# %%
print("Study Hours Std:", df["Study_Hours"].std())
print("Attendance Std:", df["Attendance"].std())
print("Assignment Score Std:", df["Assignment_Score"].std())
print("Exam Score Std:", df["Exam_Score"].std())
# Out:
# Study Hours Std: 2.625281939746262
# Attendance Std: 11.731199965543974
# Assignment Score Std: 13.113271702242812
# Exam Score Std: 13.356941818277196

# %%
summary = pd.DataFrame({
    "Mean": df[["Study_Hours", "Attendance", "Assignment_Score", "Exam_Score"]].mean(),
    "Minimum": df[["Study_Hours", "Attendance", "Assignment_Score", "Exam_Score"]].min(),
    "Maximum": df[["Study_Hours", "Attendance", "Assignment_Score", "Exam_Score"]].max(),
    "Standard Deviation": df[["Study_Hours", "Attendance", "Assignment_Score", "Exam_Score"]].std()
})

summary
# Out:
#                    Mean  Minimum  Maximum  Standard Deviation
# Study_Hours        5.05        1       10            2.625282
# Attendance        79.40       55       98           11.731200
# Assignment_Score  75.80       50       96           13.113272
# Exam_Score        73.75       48       95           13.356942

# %%
plt.figure(figsize=(8, 5))

sns.histplot(
    df["Exam_Score"],
    bins=8,
    kde=True
)

plt.title("Distribution of Exam Scores")
plt.xlabel("Exam Score")
plt.ylabel("Number of Students")

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.histplot(df["Exam_Score"], bins=8, kde=True)

plt.title("Distribution of Exam Scores")
plt.xlabel("Exam Score")
plt.ylabel("Number of Students")

plt.savefig("exam_score_distribution.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df[[
        "Study_Hours",
        "Attendance",
        "Assignment_Score",
        "Exam_Score"
    ]]
)

plt.title("Boxplot for Outlier Detection")
plt.xlabel("Variables")
plt.ylabel("Values")

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df[[
        "Study_Hours",
        "Attendance",
        "Assignment_Score",
        "Exam_Score"
    ]]
)

plt.title("Boxplot for Outlier Detection")
plt.xlabel("Variables")
plt.ylabel("Values")

plt.savefig("outlier_boxplot.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
Q1 = df["Exam_Score"].quantile(0.25)
Q3 = df["Exam_Score"].quantile(0.75)

IQR = Q3 - Q1

lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR

print("Q1:", Q1)
print("Q3:", Q3)
print("IQR:", IQR)
print("Lower Limit:", lower_limit)
print("Upper Limit:", upper_limit)
# Out:
# Q1: 64.25
# Q3: 83.5
# IQR: 19.25
# Lower Limit: 35.375
# Upper Limit: 112.375

# %%
outliers = df[
    (df["Exam_Score"] < lower_limit) |
    (df["Exam_Score"] > upper_limit)
]

print("Possible Exam Score Outliers:")
display(outliers)
# Out:
# Possible Exam Score Outliers:
# Empty DataFrame
# Columns: [Student, Study_Hours, Attendance, Assignment_Score, Exam_Score]
# Index: []

# %%
plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=df,
    x="Study_Hours",
    y="Exam_Score"
)

plt.title("Study Hours vs Exam Score")
plt.xlabel("Study Hours")
plt.ylabel("Exam Score")

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=df,
    x="Study_Hours",
    y="Exam_Score"
)

plt.title("Study Hours vs Exam Score")
plt.xlabel("Study Hours")
plt.ylabel("Exam Score")

plt.savefig("study_hours_vs_exam_score.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=df,
    x="Attendance",
    y="Exam_Score"
)

plt.title("Attendance vs Exam Score")
plt.xlabel("Attendance (%)")
plt.ylabel("Exam Score")

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=df,
    x="Attendance",
    y="Exam_Score"
)

plt.title("Attendance vs Exam Score")
plt.xlabel("Attendance (%)")
plt.ylabel("Exam Score")

plt.savefig("attendance_vs_exam_score.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=df,
    x="Assignment_Score",
    y="Exam_Score"
)

plt.title("Assignment Score vs Exam Score")
plt.xlabel("Assignment Score")
plt.ylabel("Exam Score")

plt.savefig("assignment_vs_exam_score.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=df,
    x="Assignment_Score",
    y="Exam_Score"
)

plt.title("Assignment Score vs Exam Score")
plt.xlabel("Assignment Score")
plt.ylabel("Exam Score")

plt.show()

# %%
correlation = df[
    ["Study_Hours", "Attendance", "Assignment_Score", "Exam_Score"]
].corr()

print(correlation)
# Out:
#                   Study_Hours  Attendance  Assignment_Score  Exam_Score
# Study_Hours          1.000000    0.980251          0.986402    0.987994
# Attendance           0.980251    1.000000          0.996492    0.996921
# Assignment_Score     0.986402    0.996492          1.000000    0.999426
# Exam_Score           0.987994    0.996921          0.999426    1.000000

# %%
plt.figure(figsize=(8, 6))

sns.heatmap(
    correlation,
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Heatmap")

plt.show()

# %%
plt.figure(figsize=(8, 6))

sns.heatmap(
    correlation,
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Heatmap")

plt.savefig("correlation_heatmap.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
exam_correlation = correlation["Exam_Score"].sort_values(ascending=False)

print(exam_correlation)
# Out:
# Exam_Score          1.000000
# Assignment_Score    0.999426
# Attendance          0.996921
# Study_Hours         0.987994
# Name: Exam_Score, dtype: float64

# %%
average_scores = [
    df["Assignment_Score"].mean(),
    df["Exam_Score"].mean()
]

labels = [
    "Assignment Score",
    "Exam Score"
]

plt.figure(figsize=(7, 5))

plt.bar(labels, average_scores)

plt.title("Average Assignment and Exam Scores")
plt.xlabel("Assessment Type")
plt.ylabel("Average Score")

plt.show()

# %%
plt.figure(figsize=(7, 5))

plt.bar(labels, average_scores)

plt.title("Average Assignment and Exam Scores")
plt.xlabel("Assessment Type")
plt.ylabel("Average Score")

plt.savefig("average_scores.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
highest = df.loc[df["Exam_Score"].idxmax()]

print("Highest Exam Score Student:")
display(highest)
# Out:
# Highest Exam Score Student:
# Student             Student 17
# Study_Hours                 10
# Attendance                  98
# Assignment_Score            96
# Exam_Score                  95
# Name: 16, dtype: object

# %%
lowest = df.loc[df["Exam_Score"].idxmin()]

print("Lowest Exam Score Student:")
display(lowest)
# Out:
# Lowest Exam Score Student:
# Student             Student 18
# Study_Hours                  1
# Attendance                  55
# Assignment_Score            50
# Exam_Score                  48
# Name: 17, dtype: object

# %%
study_exam_corr = df["Study_Hours"].corr(df["Exam_Score"])

print("Correlation between Study Hours and Exam Score:",
      round(study_exam_corr, 2))
# Out:
# Correlation between Study Hours and Exam Score: 0.99

# %%
if study_exam_corr > 0:
    print("There is a positive relationship between study hours and exam scores.")
elif study_exam_corr < 0:
    print("There is a negative relationship between study hours and exam scores.")
else:
    print("There is no linear relationship.")
# Out:
# There is a positive relationship between study hours and exam scores.

# %%
print("Study Hours Range:",
      df["Study_Hours"].min(),
      "to",
      df["Study_Hours"].max())

print("Attendance Range:",
      df["Attendance"].min(),
      "to",
      df["Attendance"].max())

print("Assignment Score Range:",
      df["Assignment_Score"].min(),
      "to",
      df["Assignment_Score"].max())

print("Exam Score Range:",
      df["Exam_Score"].min(),
      "to",
      df["Exam_Score"].max())
# Out:
# Study Hours Range: 1 to 10
# Attendance Range: 55 to 98
# Assignment Score Range: 50 to 96
# Exam Score Range: 48 to 95

# %%
findings = pd.DataFrame({
    "Analysis": [
        "Missing Values",
        "Duplicate Records",
        "Study Hours vs Exam Score",
        "Attendance vs Exam Score",
        "Assignment Score vs Exam Score"
    ],
    "Result": [
        df.isnull().sum().sum(),
        df.duplicated().sum(),
        round(df["Study_Hours"].corr(df["Exam_Score"]), 2),
        round(df["Attendance"].corr(df["Exam_Score"]), 2),
        round(df["Assignment_Score"].corr(df["Exam_Score"]), 2)
    ]
})

findings
# Out:
#                          Analysis  Result
# 0                  Missing Values    0.00
# 1               Duplicate Records    0.00
# 2       Study Hours vs Exam Score    0.99
# 3        Attendance vs Exam Score    1.00
# 4  Assignment Score vs Exam Score    1.00

# %% [markdown]
# ## Final Insights and Conclusion
#
# ### Key Insights
# 1. Students with higher study hours generally achieved higher exam scores.
# 2. Attendance has a positive relationship with exam performance.
# 3. Assignment scores are positively related to exam scores.
# 4. Correlation analysis helped identify relationships between numerical variables.
# 5. Outlier analysis helped identify unusual student performance values.
# 6. The dataset was checked for missing values and duplicate records.
#
# ### Conclusion
# Exploratory Data Analysis helped us understand the student performance dataset through data cleaning, statistical analysis, visualization, correlation analysis, and outlier detection. The analysis shows that study habits, attendance, and assignment performance can provide useful insights into students' exam performance.
